# %% [markdown]
# # LOAD EXCEL FILE / save as json file

# %%
import pandas as pd

# %%
df = pd.read_excel("C:\\Users\\User\\Desktop\\HOME EXPENSES.xlsx")

# %%
df
# Out:
#         DAYS           EXPENSES      FOOD       EON OUTSIDE    MARKET  \
# 0     Column1            Column2   Column3  Column4  Column5  Column6
# 1     Monday                 NaN       NaN      NaN      NaN      NaN
# 2     Tuesday                NaN         0        0      130        0
# 3   Wednesday                NaN        60       50      150        0
# 4    Thursday                NaN       NaN       50      160        0
# 5      Friday                NaN       NaN       90        0        0
# 6    Saturday                NaN        35        0        0        0
# 7      Sunday                NaN       NaN       43        0        0
# 8      Monday                NaN        57        0        0        0
# 9     Tuesday                NaN        40       30        0        0
# 10  Wednesday                NaN        70       20       40        0
# 11   Thursday                NaN       110        0        0        0
# ...

# %% [markdown]
# # DF to json file

# %%
json = df.to_json("homeexpenses.json")
