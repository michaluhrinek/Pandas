# %% [markdown]
# # READ TEXT FILE

# %%
import pandas as pd

# %%
with open(file='links.txt',mode='r') as f:
    text = f.read()

# %%
print(text)
# Out:
# https://medium.com/analytics-vidhya/how-to-summarize-data-with-pandas-2c9edffafbaf#dee7
#
# https://dataindependent.com/pandas/pandas-dataframe-from-dict-pd-df-from_dict/
#
# https://towardsdatascience.com/step-by-step-tutorial-web-scraping-wikipedia-with-beautifulsoup-48d7f2dfa52d
#
# https://github.com/Hamza-Elhaj/SpaceX-Falcon9-Project--/blob/main/3%20Data%20wrangling.ipynb
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.jaccard_score.html
#
# https://reward.skills.network/claim
#
# https://codekarim.com/sites/default/files/ML0101EN-Clas-Decision-Trees-drug-py-v1.html
#
#
# youtube:
# https://www.youtube.com/watch?v=vmEHCJofslg
# https://www.youtube.com/results?search_query=SQL+zero+to+hero
# https://www.youtube.com/watch?v=QpBmO35pmVE
# https://www.youtube.com/watch?v=Il04RjS-9-8
# https://www.youtube.com/watch?v=6rDqwji7eMc
# https://www.youtube.com/watch?v=uXxmOoWTyM8
# ...
